# %% [markdown]
# Data Preparation Summary

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Data/E Commerce Customer Insights and Churn Dataset.csv')
df.head()
# Out:
#   order_id customer_id  age product_id   country signup_date  \
# 0  ORD5000    CUST1000   39    PROD200    Canada    1/7/2021
# 1  ORD5001    CUST1001   61    PROD201       USA  10/19/2020
# 2  ORD5002    CUST1002   26    PROD202  Pakistan   6/10/2023
# 3  ORD5003    CUST1003   54    PROD203     India   7/30/2023
# 4  ORD5004    CUST1004   50    PROD204     India   12/9/2020
#
#   last_purchase_date  cancellations_count subscription_status order_date  \
# 0          2/21/2023                    0              active  8/20/2024
# 1          12/8/2021                    0              active  7/17/2025
# 2           9/4/2023                    3           cancelled  3/12/2025
# 3          2/20/2024                    4              paused  9/19/2024
# 4          9/14/2024                    0              active   8/8/2024
#
#    unit_price  quantity  purchase_frequency preferred_category  product_name  \
# 0       78.21         5                  37             Sports      Football
# 1       64.02         8                  35             Sports  Refrigerator
# 2      604.14         2                  44        Electronics        Hoodie
# 3       84.66         4                   1             Sports   Conditioner
# 4       62.66         7                  35             Sports    Smartwatch
#
#       category  gender
# 0       Sports  Female
# 1         Home  Female
# 2     Clothing  Female
# 3       Beauty    Male
# 4  Electronics    Male

# %%
df.shape
# Out:
# (2000, 17)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             2000 non-null   str
#  1   customer_id          2000 non-null   str
#  2   age                  2000 non-null   int64
#  3   product_id           2000 non-null   str
#  4   country              2000 non-null   str
#  5   signup_date          2000 non-null   str
#  6   last_purchase_date   2000 non-null   str
#  7   cancellations_count  2000 non-null   int64
#  8   subscription_status  2000 non-null   str
#  9   order_date           2000 non-null   str
#  10  unit_price           2000 non-null   float64
#  11  quantity             2000 non-null   int64
#  12  purchase_frequency   2000 non-null   int64
#  13  preferred_category   2000 non-null   str
#  14  product_name         2000 non-null   str
#  15  category             2000 non-null   str
#  16  gender               2000 non-null   str
# dtypes: float64(1), int64(4), str(12)
# memory usage: 265.8 KB

# %%
df.isnull().sum()
# Out:
# order_id               0
# customer_id            0
# age                    0
# product_id             0
# country                0
# signup_date            0
# last_purchase_date     0
# cancellations_count    0
# subscription_status    0
# order_date             0
# unit_price             0
# quantity               0
# purchase_frequency     0
# preferred_category     0
# product_name           0
# category               0
# gender                 0
# dtype: int64

# %%
df.describe()
# Out:
#                age  cancellations_count   unit_price     quantity  \
# count  2000.000000          2000.000000  2000.000000  2000.000000
# mean     44.080500             2.441500   324.719460     4.948500
# std      14.798091             1.702359   361.548405     2.557757
# min      18.000000             0.000000     2.850000     1.000000
# 25%      31.000000             1.000000   111.127500     3.000000
# 50%      45.000000             2.000000   206.515000     5.000000
# 75%      57.000000             4.000000   384.507500     7.000000
# max      69.000000             5.000000  1991.630000     9.000000
#
#        purchase_frequency
# count         2000.000000
# mean            25.158000
# std             14.158752
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             37.000000
# max             49.000000

# %%
date_cols = ['signup_date','order_date', 'last_purchase_date']

for col in date_cols:
    df[col] = pd.to_datetime(df[col])

df[date_cols].dtypes
# Out:
# signup_date           datetime64[us]
# order_date            datetime64[us]
# last_purchase_date    datetime64[us]
# dtype: object

# %%
df['order_amount'] = df['quantity'] * df['unit_price'] # total_spendings

# %%
reference_date = df['last_purchase_date'].max() + pd.Timedelta(days=1)  # Reference date
reference_date
# Out:
# Timestamp('2025-08-21 00:00:00')

# %%
# RFM features
df['recency_days'] = (reference_date - df['last_purchase_date']).dt.days
df['frequency'] = df['purchase_frequency']
df['monetary'] = df['order_amount']

# %%
#drop 'purchase_frequency' column
df.drop(columns=['purchase_frequency'], inplace = True)

# %%
# 2.2.1 Disclose customer lifecycle
df['tenure_days'] = (reference_date - df['signup_date']).dt.days
df['avg_order_value'] = np.where(df['frequency']>0,df['monetary']/df['frequency'],0)
# 2.2.2 Engagement
df['purchase_intensity'] = np.where(df['tenure_days'] > 0,df['frequency'] / df['tenure_days'],0)
df['inactive_ratio'] = np.where(df['tenure_days']>0,df['recency_days']/df['tenure_days'],0)

# %% [markdown]
# 3. Check Outlier

# %%
# Non numerical columns
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['order_id', 'customer_id', 'product_id', 'country',
#        'subscription_status', 'preferred_category', 'product_name', 'category',
#        'gender'],
#       dtype='str')

# %%
for col in cat_cols:
    print(f"{col}:{df[col].nunique()} unique value")  # Number of unique values
# Out:
# order_id:2000 unique value
# customer_id:2000 unique value
# product_id:2000 unique value
# country:6 unique value
# subscription_status:3 unique value
# preferred_category:5 unique value
# product_name:40 unique value
# category:5 unique value
# gender:3 unique value

# %%
# Check unique values
for col in cat_cols:
    print(f"\n{col}:")
    print(df[col].unique())
# Out:
# order_id:
# <StringArray>
# ['ORD5000', 'ORD5001', 'ORD5002', 'ORD5003', 'ORD5004', 'ORD5005', 'ORD5006',
#  'ORD5007', 'ORD5008', 'ORD5009',
#  ...
#  'ORD6990', 'ORD6991', 'ORD6992', 'ORD6993', 'ORD6994', 'ORD6995', 'ORD6996',
#  'ORD6997', 'ORD6998', 'ORD6999']
# Length: 2000, dtype: str
#
# customer_id:
# <StringArray>
# ['CUST1000', 'CUST1001', 'CUST1002', 'CUST1003', 'CUST1004', 'CUST1005',
#  'CUST1006', 'CUST1007', 'CUST1008', 'CUST1009',
#  ...
#  'CUST2990', 'CUST2991', 'CUST2992', 'CUST2993', 'CUST2994', 'CUST2995',
#  'CUST2996', 'CUST2997', 'CUST2998', 'CUST2999']
# Length: 2000, dtype: str
#
# product_id:
# <StringArray>
# [ 'PROD200',  'PROD201',  'PROD202',  'PROD203',  'PROD204',  'PROD205',
#   'PROD206',  'PROD207',  'PROD208',  'PROD209',
#  ...
#  'PROD2190', 'PROD2191', 'PROD2192', 'PROD2193', 'PROD2194', 'PROD2195',
#  'PROD2196', 'PROD2197', 'PROD2198', 'PROD2199']
# Length: 2000, dtype: str
#
# country:
# <StringArray>
# ['Canada', 'USA', 'Pakistan', 'India', 'Germany', 'UK']
# Length: 6, dtype: str
#
# subscription_status:
# <StringArray>
# ['active', 'cancelled', 'paused']
# Length: 3, dtype: str
#
# preferred_category:
# <StringArray>
# ['Sports', 'Electronics', 'Clothing', 'Home', 'Beauty']
# Length: 5, dtype: str
#
# product_name:
# <StringArray>
# [         'Football',      'Refrigerator',            'Hoodie',
#        'Conditioner',        'Smartwatch',            'Tablet',
#             'Jacket',       'Nail Polish',            'Camera',
#          'Dumbbells',        'Headphones',    'Vacuum Cleaner',
#            'Perfume',    'Cycling Helmet',         'Face Wash',
#        'Cricket Bat',          'Sneakers',             'Dress',
#         'Smartphone',          'Lipstick',           'T-Shirt',
#      'Tennis Racket',              'Sofa',            'Laptop',
#         'Basketball',             'Shirt',           'Blender',
#               'Lamp', 'Bluetooth Speaker',    'Gaming Console',
#              'Jeans',     'Running Shoes',        'Foundation',
#              'Chair',      'Dining Table',       'Moisturizer',
#           'Yoga Mat',           'Shampoo',             'Skirt',
#          'Microwave']
# Length: 40, dtype: str
#
# category:
# <StringArray>
# ['Sports', 'Home', 'Clothing', 'Beauty', 'Electronics']
# Length: 5, dtype: str
#
# gender:
# <StringArray>
# ['Female', 'Male', 'Other']
# Length: 3, dtype: str

# %%
# Value counts
for col in cat_cols:
    print(f"\n{col} distribution:")
    print(df[col].value_counts())
# Out:
# order_id distribution:
# order_id
# ORD5000    1
# ORD5001    1
# ORD5002    1
# ORD5003    1
# ORD5004    1
#           ..
# ORD6995    1
# ORD6996    1
# ORD6997    1
# ORD6998    1
# ORD6999    1
# Name: count, Length: 2000, dtype: int64
#
# customer_id distribution:
# customer_id
# CUST1000    1
# CUST1001    1
# CUST1002    1
# CUST1003    1
# CUST1004    1
#            ..
# CUST2995    1
# CUST2996    1
# CUST2997    1
# CUST2998    1
# CUST2999    1
# Name: count, Length: 2000, dtype: int64
#
# product_id distribution:
# product_id
# PROD200     1
# PROD201     1
# PROD202     1
# PROD203     1
# PROD204     1
#            ..
# PROD2195    1
# PROD2196    1
# PROD2197    1
# PROD2198    1
# PROD2199    1
# Name: count, Length: 2000, dtype: int64
#
# country distribution:
# country
# Germany     360
# UK          350
# Pakistan    332
# India       324
# USA         319
# Canada      315
# Name: count, dtype: int64
#
# subscription_status distribution:
# subscription_status
# active       1204
# cancelled     493
# paused        303
# Name: count, dtype: int64
#
# preferred_category distribution:
# preferred_category
# Clothing       419
# Electronics    401
# Sports         399
# Home           399
# Beauty         382
# Name: count, dtype: int64
#
# product_name distribution:
# product_name
# Sneakers             72
# Skirt                64
# Dumbbells            62
# Perfume              61
# Shirt                61
# Smartwatch           58
# Cricket Bat          57
# Smartphone           57
# Camera               56
# Lipstick             56
# Bluetooth Speaker    55
# Headphones           54
# Football             53
# Laptop               53
# Face Wash            52
# Moisturizer          52
# Jacket               51
# Vacuum Cleaner       51
# Conditioner          50
# Sofa                 50
# Jeans                49
# Yoga Mat             49
# Blender              48
# Chair                48
# T-Shirt              46
# Lamp                 46
# Microwave            46
# Tablet               45
# Shampoo              45
# Hoodie               44
# Cycling Helmet       44
# Running Shoes        44
# Dining Table         44
# Foundation           43
# Refrigerator         41
# Tennis Racket        41
# Basketball           40
# Dress                39
# Nail Polish          37
# Gaming Console       36
# Name: count, dtype: int64
#
# category distribution:
# category
# Clothing       426
# Electronics    414
# Beauty         396
# Sports         390
# Home           374
# Name: count, dtype: int64
#
# gender distribution:
# gender
# Female    1015
# Male       917
# Other       68
# Name: count, dtype: int64

# %%
# Select numerical columns for outlier detection
num_cols = [
    'age', 'quantity', 'unit_price',
    'frequency', 'monetary',
    'recency_days', 'tenure_days',
    'avg_order_value', 'purchase_intensity'
]

df[num_cols].head()
# Out:
#    age  quantity  unit_price  frequency  monetary  recency_days  tenure_days  \
# 0   39         5       78.21         37    391.05           912         1687
# 1   61         8       64.02         35    512.16          1352         1767
# 2   26         2      604.14         44   1208.28           717          803
# 3   54         4       84.66          1    338.64           548          753
# 4   50         7       62.66         35    438.62           341         1716
#
#    avg_order_value  purchase_intensity
# 0        10.568919            0.021932
# 1        14.633143            0.019808
# 2        27.460909            0.054795
# 3       338.640000            0.001328
# 4        12.532000            0.020396

# %%
# Boxplots for outlier detection

plt.Figure(figsize=(15,10))

for i, col in enumerate(num_cols):
    plt.subplot(3, 4, i+1)
    sns.boxplot(x=df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
def detect_outliers_iqr(df, columns):
    outlier_summary = {}

    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

        outlier_summary[col] = len(outliers)

    return outlier_summary

# Run detection
outliers = detect_outliers_iqr(df, num_cols)

print("Outlier count per column:")
print(outliers)
# Out:
# Outlier count per column:
# {'age': 0, 'quantity': 0, 'unit_price': 186, 'frequency': 0, 'monetary': 0, 'recency_days': 0, 'tenure_days': 0, 'avg_order_value': 215, 'purchase_intensity': 11}

# %%
print('='*60)
print('final data cleaning report')
print('='*60)
# Out:
# ============================================================
# final data cleaning report
# ============================================================

# %%
# 1. Missing values
missing = df.isnull().sum()
missing_pct = (missing/ len(df))*100

missing_df = pd.DataFrame({
    'missing_count': missing,
    'missing_pct%': missing_pct.round(2)
})

missing_df = missing_df[missing_df['missing_count']>0]

print("\nmissing values per varisble :")
print(missing_df if not missing_df.empty else "No missing values")


# 2. Duplicate check
dup_count = df.duplicated().sum()
print(f"\nDuplicate rows: {dup_count}")

# 3. Unique counts (key categorical variables)
cat_cols = df.select_dtypes(include='object').columns

print("\ncategarical columns summery:")
for col in cat_cols:
    print(f"{col}:{df[col].nunique()} unique values")

# 4. Dataset structure
print(f"no of rows:{df.shape[0]}")
print(f'no of rows:{df.shape[0]}')

# 5. Customer uniqueness (VERY IMPORTANT ⭐)
unique_customer = df['customer_id'].nunique()
print(f"\nunique customer count:{unique_customer}/{len(df)}")

if unique_customer == len(df):
    print("✓ Dataset is at customer-level (no duplicates per customer)")
else:
    print('⚠ Multiple rows per customer detected')

# 6. Final check summary
print("\nOverall Data Quality Status:")
if missing_df.empty and dup_count == 0:
    print("✓ Clean dataset — no missing values and no duplicates")
else:
    print("⚠ Data requires further cleaning")

print("="*60)
# Out:
# missing values per varisble :
# No missing values
#
# Duplicate rows: 0
#
# categarical columns summery:
# order_id:2000 unique values
# customer_id:2000 unique values
# product_id:2000 unique values
# country:6 unique values
# subscription_status:3 unique values
# preferred_category:5 unique values
# product_name:40 unique values
# category:5 unique values
# gender:3 unique values
# no of rows:2000
# no of rows:2000
#
# unique customer count:2000/2000
# ✓ Dataset is at customer-level (no duplicates per customer)
#
# Overall Data Quality Status:
# ✓ Clean dataset — no missing values and no duplicates
# ============================================================

# %%
# Export cleaned dataset
df.to_csv("cleaned_ecommerce_churn_dataset.csv", index=False)
